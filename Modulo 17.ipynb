# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pytz
import csv
import os

cwd = os.getcwd() 
print("Directorio actual es: {0}".format(cwd))
# Out:
# Directorio actual es: c:\Users\Omars\Desktop\Stuff\EBAC\Módulo 2\Módulo 22.1\test_branch\test_branch

# %%
dataframe = pd.read_csv("fifa_eda.csv", encoding = 'UTF-8')
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
dataframe = dataframe.fillna(0).drop("Unnamed: 0", axis = "columns")
dataframe.shape
# Out:
# (18207, 88)

# %%
dataframe.sample(1)
# Out:
#            ID          Name  Age  \
# 17846  236737  J. Iaciofano   19
#
#                                                 Photo Nationality  \
# 17846  https://cdn.sofifa.org/players/4/19/236737.png     England
#
#                                       Flag  Overall  Potential  \
# 17846  https://cdn.sofifa.org/flags/14.png       52         65
#
#                    Club                                      Club Logo  Value  \
# 17846  Northampton Town  https://cdn.sofifa.org/teams/2/light/1930.png  €100K
#
#       Wage  Special Preferred Foot  International Reputation  Weak Foot  \
# 17846  €1K     1305          Right                       1.0        3.0
#
#        Skill Moves  Work Rate Body Type Real Face Position  Jersey Number  \
# 17846          2.0  High/ Low      Lean        No       ST           23.0
#
#              Joined Loaned From Contract Valid Until Height  Weight    LS  \
# 17846  May 11, 2017           0                 2019   5'10  141lbs  50+2
#
# ...

# %%
#Generar la media, mínimo y máximo de los jugadores en total, y por país (groupby)
paises = dataframe.groupby("Nationality").size().sort_values(ascending = False).reset_index().rename(columns = {0: "Number of Players"})
paises.head(10)
# Out:
#    Nationality  Number of Players
# 0      England               1662
# 1      Germany               1198
# 2        Spain               1072
# 3    Argentina                937
# 4       France                914
# 5       Brazil                827
# 6        Italy                702
# 7     Colombia                618
# 8        Japan                478
# 9  Netherlands                453
