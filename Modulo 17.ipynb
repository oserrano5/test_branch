# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pytz
import csv
import os

cwd = os.getcwd() 
print("Directorio actual es: {0}".format(cwd))
# Out:
# Directorio actual es: c:\Users\Omars\Desktop\Stuff\EBAC\Módulo 2\Módulo 22.1\test_branch\test_branch

# %%
dataframe = pd.read_csv("fifa_eda.csv", encoding = 'UTF-8')
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
dataframe = dataframe.fillna(0).drop("Unnamed: 0", axis = "columns")
dataframe.shape
# Out:
# (18207, 88)

# %%
dataframe.sample(1)
# Out:
#           ID        Name  Age                                           Photo  \
# 9254  197996  E. Larsson   26  https://cdn.sofifa.org/players/4/19/197996.png
#
#      Nationality                                 Flag  Overall  Potential  \
# 9254      Sweden  https://cdn.sofifa.org/flags/46.png       66         67
#
#           Club                                     Club Logo  Value Wage  \
# 9254  Malmö FF  https://cdn.sofifa.org/teams/2/light/320.png  €625K  €2K
#
#       Special Preferred Foot  International Reputation  Weak Foot  \
# 9254     1842          Right                       1.0        4.0
#
#       Skill Moves       Work Rate Body Type Real Face Position  Jersey Number  \
# 9254          2.0  Medium/ Medium    Normal        No      RWB            2.0
#
#            Joined Loaned From Contract Valid Until Height  Weight    LS    ST  \
# 9254  Jan 1, 2018           0                 2021    5'9  150lbs  58+2  58+2
#
#         RS    LW    LF    CF    RF    RW   LAM   CAM   RAM    LM   LCM    CM  \
# 9254  58+2  63+2  61+2  61+2  61+2  63+2  62+2  62+2  62+2  64+2  63+2  63+2
#
#        RCM    RM   LWB   LDM   CDM   RDM   RWB    LB   LCB    CB   RCB    RB  \
# 9254  63+2  64+2  66+2  63+2  63+2  63+2  66+2  65+2  61+2  61+2  61+2  65+2
#
#       Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 9254      72.0       52.0             43.0          64.0     49.0       63.0
#
#       Curve  FKAccuracy  LongPassing  BallControl  Acceleration  SprintSpeed  \
# 9254   62.0        62.0         61.0         61.0          69.0         75.0
#
#       Agility  Reactions  Balance  ShotPower  Jumping  Stamina  Strength  \
# 9254     74.0       60.0     79.0       67.0     77.0     82.0      64.0
#
#       LongShots  Aggression  Interceptions  Positioning  Vision  Penalties  \
# 9254       64.0        74.0           62.0         52.0    68.0       50.0
#
#       Composure  Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 9254       57.0     60.0            60.0           66.0      16.0         8.0
#
#       GKKicking  GKPositioning  GKReflexes Release Clause
# 9254        6.0            9.0        11.0          €859K
